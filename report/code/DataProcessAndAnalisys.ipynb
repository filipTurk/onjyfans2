# %%
import os
import polars as pl
import pandas as pd
from datetime import datetime
import chardet
input_df = pl.read_csv("../data/PrometnoPorociloAll.csv", encoding="Windows-1252")
output_df = pl.read_csv("../data/Joined_rtf_files.csv", encoding="utf-8")
input_df = input_df.with_columns(pl.col("Datum").str.strptime(pl.Datetime, "%m/%d/%Y %H:%M"))
output_df = output_df.with_columns(pl.col("Datum").str.strptime(pl.Datetime, "%m/%d/%Y %H:%M"))

# %%
with open("../data/PrometnoPorociloAll.csv", "rb") as f:
    print(chardet.detect(f.read(1000000)))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
def get_first_input_before_time(output_df_row, input_df):

    #'04/30/2022 18:30'
    target_datetime = dict(zip(output_df.columns, output_df_row))["Datum"]

    
    filtered = input_df.filter(
        (pl.col("Datum").dt.date() == target_datetime.date()) &
        (pl.col("Datum").dt.time() < target_datetime.time())
    )

    def print_all_rows():
        for i in range(len(filtered)):
            print(filtered.row(i))

    if filtered.height > 0:
       #print_all_rows()
       return filtered.sort("Datum").row(-1)
    else:
        return None

row_n = 4
test = get_first_input_before_time(output_df.row(row_n), input_df)
print("Target row datetime:", dict(zip(output_df.columns, output_df.row(row_n)))["Datum"])
print("\nLast row before target time:", dict(zip(input_df.columns, test))["Datum"])
# Out:
# Target row datetime: 2022-04-26 20:00:00
#
# Last row before target time: 2022-04-26 19:53:00

# %%
from html.parser import HTMLParser

class HTMLTextExtractor(HTMLParser):
    def __init__(self):
        super().__init__()
        self.text_parts = []

    def handle_data(self, data):
        self.text_parts.append(data)

    def get_text(self):
        return ''.join(self.text_parts).strip()

# %%
def generate_taffic_IO_examples(input_df, output_df, n_examples=1):
    traffic_examples = []
    #for i in range(len(output_df)):
    for i in range(n_examples):
        output_df_row = output_df.row(i)
        input_row = get_first_input_before_time(output_df_row, input_df)

        def strip_html(html):
            parser = HTMLTextExtractor()
            parser.feed(html)
            return parser.get_text()

        def parse_input_message(input_row, columns):
            row_dict = dict(zip(columns, input_row))
            message = ""
            for column in ["A1", "B1", "C1"]:
                value = row_dict.get(column)
                if value is not None and value != "NULL":
                    clean_value = strip_html(value)
                    message += f"{column}: {clean_value} "
            #print("Input message:", message.strip())
            return message.strip()

        
        def parse_output_message(output_row, columns):
            row_dict = dict(zip(columns, output_row))
            message = ""
            for column in ["content_01", "content_02", "content_03", "content_04", "content_05"]:
                if row_dict.get(column) is not None:
                    message += f"{row_dict[column]} "
            return message.strip()

        try:
            traffic_example = {
                "messages": [
                    {"role": "user", "content": parse_input_message(input_row, input_df.columns)},
                    {"role": "assistant", "content": parse_output_message(output_df_row, output_df.columns)}
                ]
            }
            traffic_examples.append(traffic_example)
        except Exception as e:
            print(f"Error processing row {i}: {e}")
            continue
    return traffic_examples

traffic_examples = generate_taffic_IO_examples(input_df, output_df, n_examples=len(output_df)-1)
#print(traffic_examples)
#print in json format
import json
#print(json.dumps(traffic_examples, indent=4, ensure_ascii=False))
# Out:
# Error processing row 1583: 'NoneType' object is not iterable
# Error processing row 2010: 'NoneType' object is not iterable
# Error processing row 2011: 'NoneType' object is not iterable
# Error processing row 2041: 'NoneType' object is not iterable
# Error processing row 2042: 'NoneType' object is not iterable
# Error processing row 2227: 'NoneType' object is not iterable
# Error processing row 3048: 'NoneType' object is not iterable
# Error processing row 4101: 'NoneType' object is not iterable
# Error processing row 4791: 'NoneType' object is not iterable
# Error processing row 7776: 'NoneType' object is not iterable
# Error processing row 9130: 'NoneType' object is not iterable
# Error processing row 9131: 'NoneType' object is not iterable
# Error processing row 9132: 'NoneType' object is not iterable
# Error processing row 9133: 'NoneType' object is not iterable
# Error processing row 9134: 'NoneType' object is not iterable
# Error processing row 9135: 'NoneType' object is not iterable
# Error processing row 9136: 'NoneType' object is not iterable
# Error processing row 9137: 'NoneType' object is not iterable
# Error processing row 9138: 'NoneType' object is not iterable
# Error processing row 9139: 'NoneType' object is not iterable
# Error processing row 9140: 'NoneType' object is not iterable
# Error processing row 9141: 'NoneType' object is not iterable
# Error processing row 9142: 'NoneType' object is not iterable
# Error processing row 9143: 'NoneType' object is not iterable
# Error processing row 9144: 'NoneType' object is not iterable
# Error processing row 9145: 'NoneType' object is not iterable
# Error processing row 9146: 'NoneType' object is not iterable
# Error processing row 9147: 'NoneType' object is not iterable
# Error processing row 9148: 'NoneType' object is not iterable
# Error processing row 9149: 'NoneType' object is not iterable
# Error processing row 9150: 'NoneType' object is not iterable
# Error processing row 9151: 'NoneType' object is not iterable
# Error processing row 9152: 'NoneType' object is not iterable
# Error processing row 9153: 'NoneType' object is not iterable
# Error processing row 9154: 'NoneType' object is not iterable
# Error processing row 9155: 'NoneType' object is not iterable
# Error processing row 9156: 'NoneType' object is not iterable
# Error processing row 9157: 'NoneType' object is not iterable
# Error processing row 9158: 'NoneType' object is not iterable
# Error processing row 9159: 'NoneType' object is not iterable
# Error processing row 9160: 'NoneType' object is not iterable
# Error processing row 9161: 'NoneType' object is not iterable
# Error processing row 9162: 'NoneType' object is not iterable
# Error processing row 9163: 'NoneType' object is not iterable
# Error processing row 9164: 'NoneType' object is not iterable
# Error processing row 9165: 'NoneType' object is not iterable
# Error processing row 9166: 'NoneType' object is not iterable
# Error processing row 9167: 'NoneType' object is not iterable
# Error processing row 9168: 'NoneType' object is not iterable
# Error processing row 9169: 'NoneType' object is not iterable
# Error processing row 9170: 'NoneType' object is not iterable
# Error processing row 9171: 'NoneType' object is not iterable
# Error processing row 9172: 'NoneType' object is not iterable
# Error processing row 9173: 'NoneType' object is not iterable
# Error processing row 9174: 'NoneType' object is not iterable
# Error processing row 9175: 'NoneType' object is not iterable
# Error processing row 9176: 'NoneType' object is not iterable
# Error processing row 9177: 'NoneType' object is not iterable
# Error processing row 9178: 'NoneType' object is not iterable
# Error processing row 9179: 'NoneType' object is not iterable
# Error processing row 9180: 'NoneType' object is not iterable
# Error processing row 9181: 'NoneType' object is not iterable
# Error processing row 9182: 'NoneType' object is not iterable
# Error processing row 9183: 'NoneType' object is not iterable
# Error processing row 9184: 'NoneType' object is not iterable
# Error processing row 9185: 'NoneType' object is not iterable
# Error processing row 9186: 'NoneType' object is not iterable
# Error processing row 9187: 'NoneType' object is not iterable
# Error processing row 9188: 'NoneType' object is not iterable
# Error processing row 9189: 'NoneType' object is not iterable
# Error processing row 9190: 'NoneType' object is not iterable
# Error processing row 9191: 'NoneType' object is not iterable
# Error processing row 9192: 'NoneType' object is not iterable
# Error processing row 9193: 'NoneType' object is not iterable
# Error processing row 9194: 'NoneType' object is not iterable
# Error processing row 9195: 'NoneType' object is not iterable
# Error processing row 9196: 'NoneType' object is not iterable
# Error processing row 9197: 'NoneType' object is not iterable
# Error processing row 9198: 'NoneType' object is not iterable
# Error processing row 9199: 'NoneType' object is not iterable
# Error processing row 9200: 'NoneType' object is not iterable
# Error processing row 9201: 'NoneType' object is not iterable
# Error processing row 9202: 'NoneType' object is not iterable
# Error processing row 9203: 'NoneType' object is not iterable
# Error processing row 9204: 'NoneType' object is not iterable
# Error processing row 9205: 'NoneType' object is not iterable
# Error processing row 9206: 'NoneType' object is not iterable
# Error processing row 9207: 'NoneType' object is not iterable
# Error processing row 9208: 'NoneType' object is not iterable
# Error processing row 9209: 'NoneType' object is not iterable
# Error processing row 9210: 'NoneType' object is not iterable
# Error processing row 9211: 'NoneType' object is not iterable
# Error processing row 9212: 'NoneType' object is not iterable
# Error processing row 9213: 'NoneType' object is not iterable
# Error processing row 9214: 'NoneType' object is not iterable
# Error processing row 9215: 'NoneType' object is not iterable
# Error processing row 9216: 'NoneType' object is not iterable
# Error processing row 9217: 'NoneType' object is not iterable
# Error processing row 9218: 'NoneType' object is not iterable
# Error processing row 9219: 'NoneType' object is not iterable
# Error processing row 9220: 'NoneType' object is not iterable
# Error processing row 9221: 'NoneType' object is not iterable
# Error processing row 9222: 'NoneType' object is not iterable
# Error processing row 9223: 'NoneType' object is not iterable
# Error processing row 9224: 'NoneType' object is not iterable
# Error processing row 9225: 'NoneType' object is not iterable
# Error processing row 9226: 'NoneType' object is not iterable
# Error processing row 9227: 'NoneType' object is not iterable
# Error processing row 9228: 'NoneType' object is not iterable
# Error processing row 9229: 'NoneType' object is not iterable
# Error processing row 9230: 'NoneType' object is not iterable
# Error processing row 9231: 'NoneType' object is not iterable
# Error processing row 9232: 'NoneType' object is not iterable
# Error processing row 9233: 'NoneType' object is not iterable
# Error processing row 9234: 'NoneType' object is not iterable
# Error processing row 9235: 'NoneType' object is not iterable
# Error processing row 9236: 'NoneType' object is not iterable
# Error processing row 9237: 'NoneType' object is not iterable
# Error processing row 9238: 'NoneType' object is not iterable
# Error processing row 9239: 'NoneType' object is not iterable
# Error processing row 9240: 'NoneType' object is not iterable
# Error processing row 9241: 'NoneType' object is not iterable
# Error processing row 9242: 'NoneType' object is not iterable
# Error processing row 9243: 'NoneType' object is not iterable
# Error processing row 9244: 'NoneType' object is not iterable
# Error processing row 9245: 'NoneType' object is not iterable
# Error processing row 9246: 'NoneType' object is not iterable
# Error processing row 9247: 'NoneType' object is not iterable
# Error processing row 9248: 'NoneType' object is not iterable
# Error processing row 9249: 'NoneType' object is not iterable
# Error processing row 9250: 'NoneType' object is not iterable
# Error processing row 9251: 'NoneType' object is not iterable
# Error processing row 9252: 'NoneType' object is not iterable
# Error processing row 9253: 'NoneType' object is not iterable
# Error processing row 9254: 'NoneType' object is not iterable
# Error processing row 9255: 'NoneType' object is not iterable
# Error processing row 9256: 'NoneType' object is not iterable
# Error processing row 9257: 'NoneType' object is not iterable
# Error processing row 9258: 'NoneType' object is not iterable
# Error processing row 9259: 'NoneType' object is not iterable
# Error processing row 9260: 'NoneType' object is not iterable
# Error processing row 9261: 'NoneType' object is not iterable
# Error processing row 9262: 'NoneType' object is not iterable
# Error processing row 9263: 'NoneType' object is not iterable
# Error processing row 9264: 'NoneType' object is not iterable
# Error processing row 9265: 'NoneType' object is not iterable
# Error processing row 9266: 'NoneType' object is not iterable
# Error processing row 9267: 'NoneType' object is not iterable
# Error processing row 9268: 'NoneType' object is not iterable
# Error processing row 9269: 'NoneType' object is not iterable
# Error processing row 9270: 'NoneType' object is not iterable
# Error processing row 9271: 'NoneType' object is not iterable
# Error processing row 9272: 'NoneType' object is not iterable
# Error processing row 9273: 'NoneType' object is not iterable
# Error processing row 9274: 'NoneType' object is not iterable
# Error processing row 9275: 'NoneType' object is not iterable
# Error processing row 9276: 'NoneType' object is not iterable
# Error processing row 9277: 'NoneType' object is not iterable
# Error processing row 9278: 'NoneType' object is not iterable
# Error processing row 9279: 'NoneType' object is not iterable
# Error processing row 9280: 'NoneType' object is not iterable
# Error processing row 9281: 'NoneType' object is not iterable
# Error processing row 9282: 'NoneType' object is not iterable
# Error processing row 9283: 'NoneType' object is not iterable
# Error processing row 9284: 'NoneType' object is not iterable
# Error processing row 9285: 'NoneType' object is not iterable
# Error processing row 9286: 'NoneType' object is not iterable
# Error processing row 9287: 'NoneType' object is not iterable
# Error processing row 9288: 'NoneType' object is not iterable
# Error processing row 9289: 'NoneType' object is not iterable
# Error processing row 9290: 'NoneType' object is not iterable
# Error processing row 9291: 'NoneType' object is not iterable
# Error processing row 9292: 'NoneType' object is not iterable
# Error processing row 9293: 'NoneType' object is not iterable
# Error processing row 9294: 'NoneType' object is not iterable
# Error processing row 9295: 'NoneType' object is not iterable
# Error processing row 9296: 'NoneType' object is not iterable
# Error processing row 9297: 'NoneType' object is not iterable
# Error processing row 9298: 'NoneType' object is not iterable
# Error processing row 9299: 'NoneType' object is not iterable
# Error processing row 9300: 'NoneType' object is not iterable
# Error processing row 9301: 'NoneType' object is not iterable
# Error processing row 9302: 'NoneType' object is not iterable
# Error processing row 9303: 'NoneType' object is not iterable
# Error processing row 9304: 'NoneType' object is not iterable
# Error processing row 9305: 'NoneType' object is not iterable
# Error processing row 9306: 'NoneType' object is not iterable
# Error processing row 9307: 'NoneType' object is not iterable
# Error processing row 9308: 'NoneType' object is not iterable
# Error processing row 9309: 'NoneType' object is not iterable
# Error processing row 9310: 'NoneType' object is not iterable
# Error processing row 9311: 'NoneType' object is not iterable
# Error processing row 9312: 'NoneType' object is not iterable
# Error processing row 9313: 'NoneType' object is not iterable
# Error processing row 9314: 'NoneType' object is not iterable
# Error processing row 9315: 'NoneType' object is not iterable
# Error processing row 9316: 'NoneType' object is not iterable
# Error processing row 9317: 'NoneType' object is not iterable
# Error processing row 9318: 'NoneType' object is not iterable
# Error processing row 9319: 'NoneType' object is not iterable
# Error processing row 9320: 'NoneType' object is not iterable
# Error processing row 9321: 'NoneType' object is not iterable
# Error processing row 9322: 'NoneType' object is not iterable
# Error processing row 9323: 'NoneType' object is not iterable
# Error processing row 9324: 'NoneType' object is not iterable
# Error processing row 9325: 'NoneType' object is not iterable
# Error processing row 9326: 'NoneType' object is not iterable
# Error processing row 9327: 'NoneType' object is not iterable
# Error processing row 9328: 'NoneType' object is not iterable
# Error processing row 9329: 'NoneType' object is not iterable
# Error processing row 9330: 'NoneType' object is not iterable
# Error processing row 9331: 'NoneType' object is not iterable
# Error processing row 9332: 'NoneType' object is not iterable
# Error processing row 9333: 'NoneType' object is not iterable
# Error processing row 9334: 'NoneType' object is not iterable
# Error processing row 9335: 'NoneType' object is not iterable
# Error processing row 9336: 'NoneType' object is not iterable
# Error processing row 9337: 'NoneType' object is not iterable
# Error processing row 9338: 'NoneType' object is not iterable
# Error processing row 9339: 'NoneType' object is not iterable
# Error processing row 9340: 'NoneType' object is not iterable
# Error processing row 9341: 'NoneType' object is not iterable
# Error processing row 9342: 'NoneType' object is not iterable
# Error processing row 9343: 'NoneType' object is not iterable
# Error processing row 9344: 'NoneType' object is not iterable
# Error processing row 9345: 'NoneType' object is not iterable
# Error processing row 9346: 'NoneType' object is not iterable
# Error processing row 9347: 'NoneType' object is not iterable
# Error processing row 9348: 'NoneType' object is not iterable
# Error processing row 9349: 'NoneType' object is not iterable
# Error processing row 9350: 'NoneType' object is not iterable
# Error processing row 9351: 'NoneType' object is not iterable
# Error processing row 9352: 'NoneType' object is not iterable
# Error processing row 9353: 'NoneType' object is not iterable
# Error processing row 9354: 'NoneType' object is not iterable
# Error processing row 9355: 'NoneType' object is not iterable
# Error processing row 9356: 'NoneType' object is not iterable
# Error processing row 9357: 'NoneType' object is not iterable
# Error processing row 9358: 'NoneType' object is not iterable
# Error processing row 9359: 'NoneType' object is not iterable
# Error processing row 9360: 'NoneType' object is not iterable
# Error processing row 9361: 'NoneType' object is not iterable
# Error processing row 9362: 'NoneType' object is not iterable
# Error processing row 9363: 'NoneType' object is not iterable
# Error processing row 9364: 'NoneType' object is not iterable
# Error processing row 9365: 'NoneType' object is not iterable
# Error processing row 9366: 'NoneType' object is not iterable
# Error processing row 9367: 'NoneType' object is not iterable
# Error processing row 9368: 'NoneType' object is not iterable
# Error processing row 9369: 'NoneType' object is not iterable
# Error processing row 9370: 'NoneType' object is not iterable
# Error processing row 9371: 'NoneType' object is not iterable
# Error processing row 9372: 'NoneType' object is not iterable
# Error processing row 9373: 'NoneType' object is not iterable
# Error processing row 9374: 'NoneType' object is not iterable
# Error processing row 9375: 'NoneType' object is not iterable
# Error processing row 9376: 'NoneType' object is not iterable
# Error processing row 9377: 'NoneType' object is not iterable
# Error processing row 9378: 'NoneType' object is not iterable
# Error processing row 9379: 'NoneType' object is not iterable
# Error processing row 9380: 'NoneType' object is not iterable
# Error processing row 9381: 'NoneType' object is not iterable
# Error processing row 9382: 'NoneType' object is not iterable
# Error processing row 9383: 'NoneType' object is not iterable
# Error processing row 9384: 'NoneType' object is not iterable
# Error processing row 9385: 'NoneType' object is not iterable
# Error processing row 9386: 'NoneType' object is not iterable
# Error processing row 9387: 'NoneType' object is not iterable
# Error processing row 9388: 'NoneType' object is not iterable
# Error processing row 9389: 'NoneType' object is not iterable
# Error processing row 9390: 'NoneType' object is not iterable
# Error processing row 9391: 'NoneType' object is not iterable
# Error processing row 9392: 'NoneType' object is not iterable
# Error processing row 9393: 'NoneType' object is not iterable
# Error processing row 9394: 'NoneType' object is not iterable
# Error processing row 9395: 'NoneType' object is not iterable
# Error processing row 9396: 'NoneType' object is not iterable
# Error processing row 9397: 'NoneType' object is not iterable
# Error processing row 9398: 'NoneType' object is not iterable
# Error processing row 9399: 'NoneType' object is not iterable
# Error processing row 9400: 'NoneType' object is not iterable
# Error processing row 9401: 'NoneType' object is not iterable
# Error processing row 9402: 'NoneType' object is not iterable
# Error processing row 9403: 'NoneType' object is not iterable
# Error processing row 9404: 'NoneType' object is not iterable
# Error processing row 9405: 'NoneType' object is not iterable
# Error processing row 9406: 'NoneType' object is not iterable
# Error processing row 9407: 'NoneType' object is not iterable
# Error processing row 9408: 'NoneType' object is not iterable
# Error processing row 9409: 'NoneType' object is not iterable
# Error processing row 9410: 'NoneType' object is not iterable
# Error processing row 9411: 'NoneType' object is not iterable
# Error processing row 9412: 'NoneType' object is not iterable
# Error processing row 9413: 'NoneType' object is not iterable
# Error processing row 9414: 'NoneType' object is not iterable
# Error processing row 9415: 'NoneType' object is not iterable
# Error processing row 9416: 'NoneType' object is not iterable
# Error processing row 9417: 'NoneType' object is not iterable
# Error processing row 9418: 'NoneType' object is not iterable
# Error processing row 9419: 'NoneType' object is not iterable
# Error processing row 9420: 'NoneType' object is not iterable
# Error processing row 9421: 'NoneType' object is not iterable
# Error processing row 9422: 'NoneType' object is not iterable
# Error processing row 9423: 'NoneType' object is not iterable
# Error processing row 9424: 'NoneType' object is not iterable
# Error processing row 9425: 'NoneType' object is not iterable
# Error processing row 9426: 'NoneType' object is not iterable
# Error processing row 9427: 'NoneType' object is not iterable
# Error processing row 9428: 'NoneType' object is not iterable
# Error processing row 9429: 'NoneType' object is not iterable
# Error processing row 9430: 'NoneType' object is not iterable
# Error processing row 9431: 'NoneType' object is not iterable
# Error processing row 9432: 'NoneType' object is not iterable
# Error processing row 9433: 'NoneType' object is not iterable
# Error processing row 9434: 'NoneType' object is not iterable
# Error processing row 9435: 'NoneType' object is not iterable
# Error processing row 9436: 'NoneType' object is not iterable
# Error processing row 9437: 'NoneType' object is not iterable
# Error processing row 9438: 'NoneType' object is not iterable
# Error processing row 9439: 'NoneType' object is not iterable
# Error processing row 9440: 'NoneType' object is not iterable
# Error processing row 9441: 'NoneType' object is not iterable
# Error processing row 9442: 'NoneType' object is not iterable
# Error processing row 9443: 'NoneType' object is not iterable
# Error processing row 9444: 'NoneType' object is not iterable
# Error processing row 9445: 'NoneType' object is not iterable
# Error processing row 9446: 'NoneType' object is not iterable
# Error processing row 9447: 'NoneType' object is not iterable
# Error processing row 9448: 'NoneType' object is not iterable
# Error processing row 9449: 'NoneType' object is not iterable
# Error processing row 9450: 'NoneType' object is not iterable
# Error processing row 9451: 'NoneType' object is not iterable
# Error processing row 9452: 'NoneType' object is not iterable
# Error processing row 9453: 'NoneType' object is not iterable
# Error processing row 9454: 'NoneType' object is not iterable
# Error processing row 9455: 'NoneType' object is not iterable
# Error processing row 9456: 'NoneType' object is not iterable
# Error processing row 9457: 'NoneType' object is not iterable
# Error processing row 9458: 'NoneType' object is not iterable
# Error processing row 9459: 'NoneType' object is not iterable
# Error processing row 9460: 'NoneType' object is not iterable
# Error processing row 9461: 'NoneType' object is not iterable
# Error processing row 9462: 'NoneType' object is not iterable
# Error processing row 9463: 'NoneType' object is not iterable
# Error processing row 9464: 'NoneType' object is not iterable
# Error processing row 9465: 'NoneType' object is not iterable
# Error processing row 9466: 'NoneType' object is not iterable
# Error processing row 9467: 'NoneType' object is not iterable
# Error processing row 9468: 'NoneType' object is not iterable
# Error processing row 9469: 'NoneType' object is not iterable
# Error processing row 9470: 'NoneType' object is not iterable
# Error processing row 9471: 'NoneType' object is not iterable
# Error processing row 9472: 'NoneType' object is not iterable
# Error processing row 9473: 'NoneType' object is not iterable
# Error processing row 9474: 'NoneType' object is not iterable
# Error processing row 9475: 'NoneType' object is not iterable
# Error processing row 9476: 'NoneType' object is not iterable
# Error processing row 9477: 'NoneType' object is not iterable
# Error processing row 9478: 'NoneType' object is not iterable
# Error processing row 9479: 'NoneType' object is not iterable
# Error processing row 9480: 'NoneType' object is not iterable
# Error processing row 9481: 'NoneType' object is not iterable
# Error processing row 9482: 'NoneType' object is not iterable
# Error processing row 9483: 'NoneType' object is not iterable
# Error processing row 9484: 'NoneType' object is not iterable
# Error processing row 9485: 'NoneType' object is not iterable
# Error processing row 9486: 'NoneType' object is not iterable
# Error processing row 9487: 'NoneType' object is not iterable
# Error processing row 9488: 'NoneType' object is not iterable
# Error processing row 9489: 'NoneType' object is not iterable
# Error processing row 9490: 'NoneType' object is not iterable
# Error processing row 9491: 'NoneType' object is not iterable
# Error processing row 9492: 'NoneType' object is not iterable
# Error processing row 9493: 'NoneType' object is not iterable
# Error processing row 9494: 'NoneType' object is not iterable
# Error processing row 9495: 'NoneType' object is not iterable
# Error processing row 9496: 'NoneType' object is not iterable
# Error processing row 9497: 'NoneType' object is not iterable
# Error processing row 9498: 'NoneType' object is not iterable
# Error processing row 9499: 'NoneType' object is not iterable
# Error processing row 9500: 'NoneType' object is not iterable
# Error processing row 9501: 'NoneType' object is not iterable
# Error processing row 9502: 'NoneType' object is not iterable
# Error processing row 9503: 'NoneType' object is not iterable
# Error processing row 9504: 'NoneType' object is not iterable
# Error processing row 9505: 'NoneType' object is not iterable
# Error processing row 9506: 'NoneType' object is not iterable
# Error processing row 9507: 'NoneType' object is not iterable
# Error processing row 9508: 'NoneType' object is not iterable
# Error processing row 9509: 'NoneType' object is not iterable
# Error processing row 9510: 'NoneType' object is not iterable
# Error processing row 9511: 'NoneType' object is not iterable
# Error processing row 9512: 'NoneType' object is not iterable
# Error processing row 9513: 'NoneType' object is not iterable
# Error processing row 9514: 'NoneType' object is not iterable
# Error processing row 9515: 'NoneType' object is not iterable
# Error processing row 9516: 'NoneType' object is not iterable
# Error processing row 9517: 'NoneType' object is not iterable
# Error processing row 9518: 'NoneType' object is not iterable
# Error processing row 9519: 'NoneType' object is not iterable
# Error processing row 9520: 'NoneType' object is not iterable
# Error processing row 9521: 'NoneType' object is not iterable
# Error processing row 9522: 'NoneType' object is not iterable
# Error processing row 9523: 'NoneType' object is not iterable
# Error processing row 9524: 'NoneType' object is not iterable
# Error processing row 9525: 'NoneType' object is not iterable
# Error processing row 9526: 'NoneType' object is not iterable
# Error processing row 9527: 'NoneType' object is not iterable
# Error processing row 9528: 'NoneType' object is not iterable
# Error processing row 9529: 'NoneType' object is not iterable
# Error processing row 9530: 'NoneType' object is not iterable
# Error processing row 9531: 'NoneType' object is not iterable
# Error processing row 9532: 'NoneType' object is not iterable
# Error processing row 9533: 'NoneType' object is not iterable
# Error processing row 9534: 'NoneType' object is not iterable
# Error processing row 9535: 'NoneType' object is not iterable
# Error processing row 9536: 'NoneType' object is not iterable
# Error processing row 9537: 'NoneType' object is not iterable
# Error processing row 9538: 'NoneType' object is not iterable
# Error processing row 9539: 'NoneType' object is not iterable
# Error processing row 9540: 'NoneType' object is not iterable
# Error processing row 9541: 'NoneType' object is not iterable
# Error processing row 9542: 'NoneType' object is not iterable
# Error processing row 9543: 'NoneType' object is not iterable
# Error processing row 9544: 'NoneType' object is not iterable
# Error processing row 9545: 'NoneType' object is not iterable
# Error processing row 9546: 'NoneType' object is not iterable
# Error processing row 9547: 'NoneType' object is not iterable
# Error processing row 9548: 'NoneType' object is not iterable
# Error processing row 9549: 'NoneType' object is not iterable
# Error processing row 9550: 'NoneType' object is not iterable
# Error processing row 9551: 'NoneType' object is not iterable
# Error processing row 9552: 'NoneType' object is not iterable
# Error processing row 9553: 'NoneType' object is not iterable
# Error processing row 9554: 'NoneType' object is not iterable
# Error processing row 9555: 'NoneType' object is not iterable
# Error processing row 9556: 'NoneType' object is not iterable
# Error processing row 9557: 'NoneType' object is not iterable
# Error processing row 9558: 'NoneType' object is not iterable
# Error processing row 9559: 'NoneType' object is not iterable
# Error processing row 9560: 'NoneType' object is not iterable
# Error processing row 9561: 'NoneType' object is not iterable
# Error processing row 9562: 'NoneType' object is not iterable
# Error processing row 9563: 'NoneType' object is not iterable
# Error processing row 9564: 'NoneType' object is not iterable
# Error processing row 9565: 'NoneType' object is not iterable
# Error processing row 9566: 'NoneType' object is not iterable
# Error processing row 9567: 'NoneType' object is not iterable
# Error processing row 9568: 'NoneType' object is not iterable
# Error processing row 9569: 'NoneType' object is not iterable
# Error processing row 9570: 'NoneType' object is not iterable
# Error processing row 9571: 'NoneType' object is not iterable
# Error processing row 9572: 'NoneType' object is not iterable
# Error processing row 9573: 'NoneType' object is not iterable
# Error processing row 9574: 'NoneType' object is not iterable
# Error processing row 9575: 'NoneType' object is not iterable
# Error processing row 9576: 'NoneType' object is not iterable
# Error processing row 9577: 'NoneType' object is not iterable
# Error processing row 9578: 'NoneType' object is not iterable
# Error processing row 9579: 'NoneType' object is not iterable
# Error processing row 9580: 'NoneType' object is not iterable
# Error processing row 9581: 'NoneType' object is not iterable
# Error processing row 9582: 'NoneType' object is not iterable
# Error processing row 9583: 'NoneType' object is not iterable
# Error processing row 9584: 'NoneType' object is not iterable
# Error processing row 9585: 'NoneType' object is not iterable
# Error processing row 9586: 'NoneType' object is not iterable
# Error processing row 9587: 'NoneType' object is not iterable
# Error processing row 9588: 'NoneType' object is not iterable
# Error processing row 9589: 'NoneType' object is not iterable
# Error processing row 9590: 'NoneType' object is not iterable
# Error processing row 9591: 'NoneType' object is not iterable
# Error processing row 9592: 'NoneType' object is not iterable
# Error processing row 9593: 'NoneType' object is not iterable
# Error processing row 9594: 'NoneType' object is not iterable
# Error processing row 9595: 'NoneType' object is not iterable
# Error processing row 9596: 'NoneType' object is not iterable
# Error processing row 9597: 'NoneType' object is not iterable
# Error processing row 9598: 'NoneType' object is not iterable
# Error processing row 9599: 'NoneType' object is not iterable
# Error processing row 9600: 'NoneType' object is not iterable
# Error processing row 9601: 'NoneType' object is not iterable
# Error processing row 9602: 'NoneType' object is not iterable
# Error processing row 9603: 'NoneType' object is not iterable
# Error processing row 9604: 'NoneType' object is not iterable
# Error processing row 9605: 'NoneType' object is not iterable
# Error processing row 9606: 'NoneType' object is not iterable
# Error processing row 9607: 'NoneType' object is not iterable
# Error processing row 9608: 'NoneType' object is not iterable
# Error processing row 9609: 'NoneType' object is not iterable
# Error processing row 9610: 'NoneType' object is not iterable
# Error processing row 9611: 'NoneType' object is not iterable
# Error processing row 9612: 'NoneType' object is not iterable
# Error processing row 9613: 'NoneType' object is not iterable
# Error processing row 9614: 'NoneType' object is not iterable
# Error processing row 9615: 'NoneType' object is not iterable
# Error processing row 9616: 'NoneType' object is not iterable
# Error processing row 9617: 'NoneType' object is not iterable
# Error processing row 9618: 'NoneType' object is not iterable
# Error processing row 9619: 'NoneType' object is not iterable
# Error processing row 9620: 'NoneType' object is not iterable
# Error processing row 9621: 'NoneType' object is not iterable
# Error processing row 9622: 'NoneType' object is not iterable
# Error processing row 9623: 'NoneType' object is not iterable
# Error processing row 9624: 'NoneType' object is not iterable
# Error processing row 9625: 'NoneType' object is not iterable
# Error processing row 9626: 'NoneType' object is not iterable
# Error processing row 9627: 'NoneType' object is not iterable
# Error processing row 9628: 'NoneType' object is not iterable
# Error processing row 9629: 'NoneType' object is not iterable
# Error processing row 9630: 'NoneType' object is not iterable
# Error processing row 9631: 'NoneType' object is not iterable
# Error processing row 9632: 'NoneType' object is not iterable
# Error processing row 9633: 'NoneType' object is not iterable
# Error processing row 9634: 'NoneType' object is not iterable
# Error processing row 9635: 'NoneType' object is not iterable
# Error processing row 9636: 'NoneType' object is not iterable
# Error processing row 9637: 'NoneType' object is not iterable
# Error processing row 9638: 'NoneType' object is not iterable
# Error processing row 9639: 'NoneType' object is not iterable
# Error processing row 9640: 'NoneType' object is not iterable
# Error processing row 9641: 'NoneType' object is not iterable
# Error processing row 9642: 'NoneType' object is not iterable
# Error processing row 9643: 'NoneType' object is not iterable
# Error processing row 9644: 'NoneType' object is not iterable
# Error processing row 9645: 'NoneType' object is not iterable
# Error processing row 9646: 'NoneType' object is not iterable
# Error processing row 9647: 'NoneType' object is not iterable
# Error processing row 9648: 'NoneType' object is not iterable
# Error processing row 9649: 'NoneType' object is not iterable
# Error processing row 9650: 'NoneType' object is not iterable
# Error processing row 9651: 'NoneType' object is not iterable
# Error processing row 9652: 'NoneType' object is not iterable
# Error processing row 9653: 'NoneType' object is not iterable
# Error processing row 9654: 'NoneType' object is not iterable
# Error processing row 9655: 'NoneType' object is not iterable
# Error processing row 9656: 'NoneType' object is not iterable
# Error processing row 9657: 'NoneType' object is not iterable
# Error processing row 9658: 'NoneType' object is not iterable
# Error processing row 9659: 'NoneType' object is not iterable
# Error processing row 9660: 'NoneType' object is not iterable
# Error processing row 9661: 'NoneType' object is not iterable
# Error processing row 9662: 'NoneType' object is not iterable
# Error processing row 9663: 'NoneType' object is not iterable
# Error processing row 9664: 'NoneType' object is not iterable
# Error processing row 9665: 'NoneType' object is not iterable
# Error processing row 9666: 'NoneType' object is not iterable
# Error processing row 9667: 'NoneType' object is not iterable
# Error processing row 9668: 'NoneType' object is not iterable
# Error processing row 9669: 'NoneType' object is not iterable
# Error processing row 9670: 'NoneType' object is not iterable
# Error processing row 9671: 'NoneType' object is not iterable
# Error processing row 9672: 'NoneType' object is not iterable
# Error processing row 9673: 'NoneType' object is not iterable
# Error processing row 9674: 'NoneType' object is not iterable
# Error processing row 9675: 'NoneType' object is not iterable
# Error processing row 9676: 'NoneType' object is not iterable
# Error processing row 9677: 'NoneType' object is not iterable
# Error processing row 9678: 'NoneType' object is not iterable
# Error processing row 9679: 'NoneType' object is not iterable
# Error processing row 9680: 'NoneType' object is not iterable
# Error processing row 9681: 'NoneType' object is not iterable
# Error processing row 9682: 'NoneType' object is not iterable
# Error processing row 9683: 'NoneType' object is not iterable
# Error processing row 9684: 'NoneType' object is not iterable
# Error processing row 9685: 'NoneType' object is not iterable
# Error processing row 9686: 'NoneType' object is not iterable
# Error processing row 9687: 'NoneType' object is not iterable
# Error processing row 9688: 'NoneType' object is not iterable
# Error processing row 9689: 'NoneType' object is not iterable
# Error processing row 9690: 'NoneType' object is not iterable
# Error processing row 9691: 'NoneType' object is not iterable
# Error processing row 9692: 'NoneType' object is not iterable
# Error processing row 9693: 'NoneType' object is not iterable
# Error processing row 9694: 'NoneType' object is not iterable
# Error processing row 9695: 'NoneType' object is not iterable
# Error processing row 9696: 'NoneType' object is not iterable
# Error processing row 9697: 'NoneType' object is not iterable
# Error processing row 9698: 'NoneType' object is not iterable
# Error processing row 9699: 'NoneType' object is not iterable
# Error processing row 9700: 'NoneType' object is not iterable
# Error processing row 9701: 'NoneType' object is not iterable
# Error processing row 9702: 'NoneType' object is not iterable
# Error processing row 9703: 'NoneType' object is not iterable
# Error processing row 9704: 'NoneType' object is not iterable
# Error processing row 9705: 'NoneType' object is not iterable
# Error processing row 9706: 'NoneType' object is not iterable
# Error processing row 9707: 'NoneType' object is not iterable
# Error processing row 9708: 'NoneType' object is not iterable
# Error processing row 9709: 'NoneType' object is not iterable
# Error processing row 9710: 'NoneType' object is not iterable
# Error processing row 9711: 'NoneType' object is not iterable
# Error processing row 9712: 'NoneType' object is not iterable
# Error processing row 9713: 'NoneType' object is not iterable
# Error processing row 9714: 'NoneType' object is not iterable
# Error processing row 9715: 'NoneType' object is not iterable
# Error processing row 9716: 'NoneType' object is not iterable
# Error processing row 9717: 'NoneType' object is not iterable
# Error processing row 9718: 'NoneType' object is not iterable
# Error processing row 9719: 'NoneType' object is not iterable
# Error processing row 9720: 'NoneType' object is not iterable
# Error processing row 9721: 'NoneType' object is not iterable
# Error processing row 9722: 'NoneType' object is not iterable
# Error processing row 9723: 'NoneType' object is not iterable
# Error processing row 9724: 'NoneType' object is not iterable
# Error processing row 9725: 'NoneType' object is not iterable
# Error processing row 9726: 'NoneType' object is not iterable
# Error processing row 9727: 'NoneType' object is not iterable
# Error processing row 9728: 'NoneType' object is not iterable
# Error processing row 9729: 'NoneType' object is not iterable
# Error processing row 9730: 'NoneType' object is not iterable
# Error processing row 9731: 'NoneType' object is not iterable
# Error processing row 9732: 'NoneType' object is not iterable
# Error processing row 9733: 'NoneType' object is not iterable
# Error processing row 9734: 'NoneType' object is not iterable
# Error processing row 9735: 'NoneType' object is not iterable
# Error processing row 9736: 'NoneType' object is not iterable
# Error processing row 9737: 'NoneType' object is not iterable
# Error processing row 9738: 'NoneType' object is not iterable
# Error processing row 9739: 'NoneType' object is not iterable
# Error processing row 9740: 'NoneType' object is not iterable
# Error processing row 9741: 'NoneType' object is not iterable
# Error processing row 9742: 'NoneType' object is not iterable
# Error processing row 9743: 'NoneType' object is not iterable
# Error processing row 9744: 'NoneType' object is not iterable
# Error processing row 9745: 'NoneType' object is not iterable
# Error processing row 9746: 'NoneType' object is not iterable
# Error processing row 9747: 'NoneType' object is not iterable
# Error processing row 9748: 'NoneType' object is not iterable
# Error processing row 9749: 'NoneType' object is not iterable
# Error processing row 9750: 'NoneType' object is not iterable
# Error processing row 9751: 'NoneType' object is not iterable
# Error processing row 9752: 'NoneType' object is not iterable
# Error processing row 9753: 'NoneType' object is not iterable
# Error processing row 9754: 'NoneType' object is not iterable
# Error processing row 9755: 'NoneType' object is not iterable
# Error processing row 9756: 'NoneType' object is not iterable
# Error processing row 9757: 'NoneType' object is not iterable
# Error processing row 9758: 'NoneType' object is not iterable
# Error processing row 9759: 'NoneType' object is not iterable
# Error processing row 9760: 'NoneType' object is not iterable
# Error processing row 9761: 'NoneType' object is not iterable
# Error processing row 9762: 'NoneType' object is not iterable
# Error processing row 9763: 'NoneType' object is not iterable
# Error processing row 9764: 'NoneType' object is not iterable
# Error processing row 9765: 'NoneType' object is not iterable
# Error processing row 9766: 'NoneType' object is not iterable
# Error processing row 9767: 'NoneType' object is not iterable
# Error processing row 9768: 'NoneType' object is not iterable
# Error processing row 9769: 'NoneType' object is not iterable
# Error processing row 9770: 'NoneType' object is not iterable
# Error processing row 9771: 'NoneType' object is not iterable
# Error processing row 9772: 'NoneType' object is not iterable
# Error processing row 9773: 'NoneType' object is not iterable
# Error processing row 9774: 'NoneType' object is not iterable
# Error processing row 9775: 'NoneType' object is not iterable
# Error processing row 9776: 'NoneType' object is not iterable
# Error processing row 9777: 'NoneType' object is not iterable
# Error processing row 9778: 'NoneType' object is not iterable
# Error processing row 9779: 'NoneType' object is not iterable
# Error processing row 9780: 'NoneType' object is not iterable
# Error processing row 9781: 'NoneType' object is not iterable
# Error processing row 9782: 'NoneType' object is not iterable
# Error processing row 9783: 'NoneType' object is not iterable
# Error processing row 9784: 'NoneType' object is not iterable
# Error processing row 9785: 'NoneType' object is not iterable
# Error processing row 9786: 'NoneType' object is not iterable
# Error processing row 9787: 'NoneType' object is not iterable
# Error processing row 9788: 'NoneType' object is not iterable
# Error processing row 9789: 'NoneType' object is not iterable
# Error processing row 9790: 'NoneType' object is not iterable
# Error processing row 9791: 'NoneType' object is not iterable
# Error processing row 9792: 'NoneType' object is not iterable
# Error processing row 9793: 'NoneType' object is not iterable
# Error processing row 9794: 'NoneType' object is not iterable
# Error processing row 9795: 'NoneType' object is not iterable
# Error processing row 9796: 'NoneType' object is not iterable
# Error processing row 9797: 'NoneType' object is not iterable
# Error processing row 9798: 'NoneType' object is not iterable
# Error processing row 9799: 'NoneType' object is not iterable
# Error processing row 9800: 'NoneType' object is not iterable
# Error processing row 9801: 'NoneType' object is not iterable
# Error processing row 9802: 'NoneType' object is not iterable
# Error processing row 9803: 'NoneType' object is not iterable
# Error processing row 9804: 'NoneType' object is not iterable
# Error processing row 9805: 'NoneType' object is not iterable
# Error processing row 9806: 'NoneType' object is not iterable
# Error processing row 9807: 'NoneType' object is not iterable
# Error processing row 9808: 'NoneType' object is not iterable
# Error processing row 9809: 'NoneType' object is not iterable
# Error processing row 9810: 'NoneType' object is not iterable
# Error processing row 9811: 'NoneType' object is not iterable
# Error processing row 9812: 'NoneType' object is not iterable
# Error processing row 9813: 'NoneType' object is not iterable
# Error processing row 9814: 'NoneType' object is not iterable
# Error processing row 9815: 'NoneType' object is not iterable
# Error processing row 9816: 'NoneType' object is not iterable
# Error processing row 9817: 'NoneType' object is not iterable
# Error processing row 9818: 'NoneType' object is not iterable
# Error processing row 9819: 'NoneType' object is not iterable
# Error processing row 9820: 'NoneType' object is not iterable
# Error processing row 9821: 'NoneType' object is not iterable
# Error processing row 9822: 'NoneType' object is not iterable
# Error processing row 9823: 'NoneType' object is not iterable
# Error processing row 9824: 'NoneType' object is not iterable
# Error processing row 9825: 'NoneType' object is not iterable
# Error processing row 9826: 'NoneType' object is not iterable
# Error processing row 9827: 'NoneType' object is not iterable
# Error processing row 9828: 'NoneType' object is not iterable
# Error processing row 9829: 'NoneType' object is not iterable
# Error processing row 9830: 'NoneType' object is not iterable
# Error processing row 9831: 'NoneType' object is not iterable
# Error processing row 9832: 'NoneType' object is not iterable
# Error processing row 9833: 'NoneType' object is not iterable
# Error processing row 9834: 'NoneType' object is not iterable
# Error processing row 9835: 'NoneType' object is not iterable
# Error processing row 9836: 'NoneType' object is not iterable
# Error processing row 9837: 'NoneType' object is not iterable
# Error processing row 9838: 'NoneType' object is not iterable
# Error processing row 9839: 'NoneType' object is not iterable
# Error processing row 9840: 'NoneType' object is not iterable
# Error processing row 9841: 'NoneType' object is not iterable
# Error processing row 9842: 'NoneType' object is not iterable
# Error processing row 9843: 'NoneType' object is not iterable
# Error processing row 9844: 'NoneType' object is not iterable
# Error processing row 9845: 'NoneType' object is not iterable
# Error processing row 9846: 'NoneType' object is not iterable
# Error processing row 9847: 'NoneType' object is not iterable
# Error processing row 9848: 'NoneType' object is not iterable
# Error processing row 9849: 'NoneType' object is not iterable
# Error processing row 9850: 'NoneType' object is not iterable
# Error processing row 9851: 'NoneType' object is not iterable
# Error processing row 9852: 'NoneType' object is not iterable
# Error processing row 9853: 'NoneType' object is not iterable
# Error processing row 9854: 'NoneType' object is not iterable
# Error processing row 9855: 'NoneType' object is not iterable
# Error processing row 9856: 'NoneType' object is not iterable
# Error processing row 9857: 'NoneType' object is not iterable
# Error processing row 9858: 'NoneType' object is not iterable
# Error processing row 9859: 'NoneType' object is not iterable
# Error processing row 9860: 'NoneType' object is not iterable
# Error processing row 9861: 'NoneType' object is not iterable
# Error processing row 9862: 'NoneType' object is not iterable
# Error processing row 9863: 'NoneType' object is not iterable
# Error processing row 9864: 'NoneType' object is not iterable
# Error processing row 9865: 'NoneType' object is not iterable
# Error processing row 9866: 'NoneType' object is not iterable
# Error processing row 9867: 'NoneType' object is not iterable
# Error processing row 9868: 'NoneType' object is not iterable
# Error processing row 9869: 'NoneType' object is not iterable
# Error processing row 9870: 'NoneType' object is not iterable
# Error processing row 9871: 'NoneType' object is not iterable
# Error processing row 9872: 'NoneType' object is not iterable
# Error processing row 9873: 'NoneType' object is not iterable
# Error processing row 9874: 'NoneType' object is not iterable
# Error processing row 9875: 'NoneType' object is not iterable
# Error processing row 9876: 'NoneType' object is not iterable
# Error processing row 9877: 'NoneType' object is not iterable
# Error processing row 9878: 'NoneType' object is not iterable
# Error processing row 9879: 'NoneType' object is not iterable
# Error processing row 9880: 'NoneType' object is not iterable
# Error processing row 9881: 'NoneType' object is not iterable
# Error processing row 9882: 'NoneType' object is not iterable
# Error processing row 9883: 'NoneType' object is not iterable
# Error processing row 9884: 'NoneType' object is not iterable
# Error processing row 9885: 'NoneType' object is not iterable
# Error processing row 9886: 'NoneType' object is not iterable
# Error processing row 9887: 'NoneType' object is not iterable
# Error processing row 9888: 'NoneType' object is not iterable
# Error processing row 9889: 'NoneType' object is not iterable
# Error processing row 9890: 'NoneType' object is not iterable
# Error processing row 9891: 'NoneType' object is not iterable
# Error processing row 9892: 'NoneType' object is not iterable
# Error processing row 9893: 'NoneType' object is not iterable
# Error processing row 9894: 'NoneType' object is not iterable
# Error processing row 9895: 'NoneType' object is not iterable
# Error processing row 9896: 'NoneType' object is not iterable
# Error processing row 9897: 'NoneType' object is not iterable
# Error processing row 9898: 'NoneType' object is not iterable
# Error processing row 9899: 'NoneType' object is not iterable
# Error processing row 9900: 'NoneType' object is not iterable
# Error processing row 9901: 'NoneType' object is not iterable
# Error processing row 9902: 'NoneType' object is not iterable
# Error processing row 9903: 'NoneType' object is not iterable
# Error processing row 9904: 'NoneType' object is not iterable
# Error processing row 9905: 'NoneType' object is not iterable
# ...
# Error processing row 23358: 'NoneType' object is not iterable
# Error processing row 23359: 'NoneType' object is not iterable
# Error processing row 23360: 'NoneType' object is not iterable
# Error processing row 23361: 'NoneType' object is not iterable
# Error processing row 23362: 'NoneType' object is not iterable
# Error processing row 23363: 'NoneType' object is not iterable
# Error processing row 23364: 'NoneType' object is not iterable
# Error processing row 23365: 'NoneType' object is not iterable
# Error processing row 23366: 'NoneType' object is not iterable
# Error processing row 23367: 'NoneType' object is not iterable
# Error processing row 23368: 'NoneType' object is not iterable
# Error processing row 23369: 'NoneType' object is not iterable
# Error processing row 23370: 'NoneType' object is not iterable
# Error processing row 23371: 'NoneType' object is not iterable
# Error processing row 23372: 'NoneType' object is not iterable
# Error processing row 23373: 'NoneType' object is not iterable
# Error processing row 23374: 'NoneType' object is not iterable
# Error processing row 23375: 'NoneType' object is not iterable
# Error processing row 23376: 'NoneType' object is not iterable
# Error processing row 23377: 'NoneType' object is not iterable
# Error processing row 23378: 'NoneType' object is not iterable
# Error processing row 23379: 'NoneType' object is not iterable
# Error processing row 23380: 'NoneType' object is not iterable
# Error processing row 23381: 'NoneType' object is not iterable
# Error processing row 23382: 'NoneType' object is not iterable
# Error processing row 23383: 'NoneType' object is not iterable
# Error processing row 23384: 'NoneType' object is not iterable
# Error processing row 23385: 'NoneType' object is not iterable
# Error processing row 23386: 'NoneType' object is not iterable
# Error processing row 23387: 'NoneType' object is not iterable
# Error processing row 23388: 'NoneType' object is not iterable
# Error processing row 23389: 'NoneType' object is not iterable
# Error processing row 23390: 'NoneType' object is not iterable
# Error processing row 23391: 'NoneType' object is not iterable
# Error processing row 23392: 'NoneType' object is not iterable
# Error processing row 23393: 'NoneType' object is not iterable
# Error processing row 23394: 'NoneType' object is not iterable
# Error processing row 23395: 'NoneType' object is not iterable
# Error processing row 23396: 'NoneType' object is not iterable
# Error processing row 23397: 'NoneType' object is not iterable
# Error processing row 23398: 'NoneType' object is not iterable
# Error processing row 23399: 'NoneType' object is not iterable
# Error processing row 23400: 'NoneType' object is not iterable
# Error processing row 23401: 'NoneType' object is not iterable
# Error processing row 23402: 'NoneType' object is not iterable
# Error processing row 23403: 'NoneType' object is not iterable
# Error processing row 23404: 'NoneType' object is not iterable
# Error processing row 23405: 'NoneType' object is not iterable
# Error processing row 23406: 'NoneType' object is not iterable
# Error processing row 23407: 'NoneType' object is not iterable
# Error processing row 23408: 'NoneType' object is not iterable
# Error processing row 23409: 'NoneType' object is not iterable
# Error processing row 23410: 'NoneType' object is not iterable
# Error processing row 23411: 'NoneType' object is not iterable
# Error processing row 23412: 'NoneType' object is not iterable
# Error processing row 23413: 'NoneType' object is not iterable
# Error processing row 23414: 'NoneType' object is not iterable
# Error processing row 23415: 'NoneType' object is not iterable
# Error processing row 23416: 'NoneType' object is not iterable
# Error processing row 23417: 'NoneType' object is not iterable
# Error processing row 23418: 'NoneType' object is not iterable
# Error processing row 23419: 'NoneType' object is not iterable
# Error processing row 23420: 'NoneType' object is not iterable
# Error processing row 23421: 'NoneType' object is not iterable
# Error processing row 23422: 'NoneType' object is not iterable
# Error processing row 23423: 'NoneType' object is not iterable
# Error processing row 23424: 'NoneType' object is not iterable
# Error processing row 23425: 'NoneType' object is not iterable
# Error processing row 23426: 'NoneType' object is not iterable
# Error processing row 23427: 'NoneType' object is not iterable
# Error processing row 23428: 'NoneType' object is not iterable
# Error processing row 23429: 'NoneType' object is not iterable
# Error processing row 23430: 'NoneType' object is not iterable
# Error processing row 23431: 'NoneType' object is not iterable
# Error processing row 23432: 'NoneType' object is not iterable
# Error processing row 23433: 'NoneType' object is not iterable
# Error processing row 23434: 'NoneType' object is not iterable
# Error processing row 23435: 'NoneType' object is not iterable
# Error processing row 23436: 'NoneType' object is not iterable
# Error processing row 23437: 'NoneType' object is not iterable
# Error processing row 23438: 'NoneType' object is not iterable
# Error processing row 23439: 'NoneType' object is not iterable
# Error processing row 23440: 'NoneType' object is not iterable
# Error processing row 23441: 'NoneType' object is not iterable
# Error processing row 23442: 'NoneType' object is not iterable
# Error processing row 23443: 'NoneType' object is not iterable
# Error processing row 23444: 'NoneType' object is not iterable
# Error processing row 23445: 'NoneType' object is not iterable
# Error processing row 23446: 'NoneType' object is not iterable
# Error processing row 23447: 'NoneType' object is not iterable
# Error processing row 23448: 'NoneType' object is not iterable
# Error processing row 23449: 'NoneType' object is not iterable
# Error processing row 23450: 'NoneType' object is not iterable
# Error processing row 23451: 'NoneType' object is not iterable
# Error processing row 23452: 'NoneType' object is not iterable
# Error processing row 23453: 'NoneType' object is not iterable
# Error processing row 23454: 'NoneType' object is not iterable
# Error processing row 23455: 'NoneType' object is not iterable
# Error processing row 23456: 'NoneType' object is not iterable
# Error processing row 23457: 'NoneType' object is not iterable
# Error processing row 23458: 'NoneType' object is not iterable
# Error processing row 23459: 'NoneType' object is not iterable
# Error processing row 23460: 'NoneType' object is not iterable
# Error processing row 23461: 'NoneType' object is not iterable
# Error processing row 23462: 'NoneType' object is not iterable
# Error processing row 23463: 'NoneType' object is not iterable
# Error processing row 23464: 'NoneType' object is not iterable
# Error processing row 23465: 'NoneType' object is not iterable
# Error processing row 23466: 'NoneType' object is not iterable
# Error processing row 23467: 'NoneType' object is not iterable
# Error processing row 23468: 'NoneType' object is not iterable
# Error processing row 23469: 'NoneType' object is not iterable
# Error processing row 23470: 'NoneType' object is not iterable
# Error processing row 23471: 'NoneType' object is not iterable
# Error processing row 23472: 'NoneType' object is not iterable
# Error processing row 23473: 'NoneType' object is not iterable
# Error processing row 23474: 'NoneType' object is not iterable
# Error processing row 23475: 'NoneType' object is not iterable
# Error processing row 23476: 'NoneType' object is not iterable
# Error processing row 23477: 'NoneType' object is not iterable
# Error processing row 23478: 'NoneType' object is not iterable
# Error processing row 23479: 'NoneType' object is not iterable
# Error processing row 23480: 'NoneType' object is not iterable
# Error processing row 23481: 'NoneType' object is not iterable
# Error processing row 23482: 'NoneType' object is not iterable
# Error processing row 23483: 'NoneType' object is not iterable
# Error processing row 23484: 'NoneType' object is not iterable
# Error processing row 23485: 'NoneType' object is not iterable
# Error processing row 23486: 'NoneType' object is not iterable
# Error processing row 23487: 'NoneType' object is not iterable
# Error processing row 23488: 'NoneType' object is not iterable
# Error processing row 23489: 'NoneType' object is not iterable
# Error processing row 23490: 'NoneType' object is not iterable
# Error processing row 23491: 'NoneType' object is not iterable
# Error processing row 23492: 'NoneType' object is not iterable
# Error processing row 23493: 'NoneType' object is not iterable
# Error processing row 23494: 'NoneType' object is not iterable
# Error processing row 23495: 'NoneType' object is not iterable
# Error processing row 23496: 'NoneType' object is not iterable
# Error processing row 23497: 'NoneType' object is not iterable
# Error processing row 23498: 'NoneType' object is not iterable
# Error processing row 23499: 'NoneType' object is not iterable
# Error processing row 23500: 'NoneType' object is not iterable
# Error processing row 23501: 'NoneType' object is not iterable
# Error processing row 23502: 'NoneType' object is not iterable
# Error processing row 23503: 'NoneType' object is not iterable
# Error processing row 23504: 'NoneType' object is not iterable
# Error processing row 23505: 'NoneType' object is not iterable
# Error processing row 23506: 'NoneType' object is not iterable
# Error processing row 23507: 'NoneType' object is not iterable
# Error processing row 23508: 'NoneType' object is not iterable
# Error processing row 23509: 'NoneType' object is not iterable
# Error processing row 23510: 'NoneType' object is not iterable
# Error processing row 23511: 'NoneType' object is not iterable
# Error processing row 23512: 'NoneType' object is not iterable
# Error processing row 23513: 'NoneType' object is not iterable
# Error processing row 23514: 'NoneType' object is not iterable
# Error processing row 23515: 'NoneType' object is not iterable
# Error processing row 23516: 'NoneType' object is not iterable
# Error processing row 23517: 'NoneType' object is not iterable
# Error processing row 23518: 'NoneType' object is not iterable
# Error processing row 23519: 'NoneType' object is not iterable
# Error processing row 23520: 'NoneType' object is not iterable
# Error processing row 23521: 'NoneType' object is not iterable
# Error processing row 23522: 'NoneType' object is not iterable
# Error processing row 23523: 'NoneType' object is not iterable
# Error processing row 23524: 'NoneType' object is not iterable
# Error processing row 23525: 'NoneType' object is not iterable
# Error processing row 23526: 'NoneType' object is not iterable
# Error processing row 23527: 'NoneType' object is not iterable
# Error processing row 23528: 'NoneType' object is not iterable
# Error processing row 23529: 'NoneType' object is not iterable
# Error processing row 23530: 'NoneType' object is not iterable
# Error processing row 23531: 'NoneType' object is not iterable
# Error processing row 23532: 'NoneType' object is not iterable
# Error processing row 23533: 'NoneType' object is not iterable
# Error processing row 23534: 'NoneType' object is not iterable
# Error processing row 23535: 'NoneType' object is not iterable
# Error processing row 23536: 'NoneType' object is not iterable
# Error processing row 23537: 'NoneType' object is not iterable
# Error processing row 23538: 'NoneType' object is not iterable
# Error processing row 23539: 'NoneType' object is not iterable
# Error processing row 23540: 'NoneType' object is not iterable
# Error processing row 23541: 'NoneType' object is not iterable
# Error processing row 23542: 'NoneType' object is not iterable
# Error processing row 23543: 'NoneType' object is not iterable
# Error processing row 23544: 'NoneType' object is not iterable
# Error processing row 23545: 'NoneType' object is not iterable
# Error processing row 23546: 'NoneType' object is not iterable
# Error processing row 23547: 'NoneType' object is not iterable
# Error processing row 23548: 'NoneType' object is not iterable
# Error processing row 23549: 'NoneType' object is not iterable
# Error processing row 23550: 'NoneType' object is not iterable
# Error processing row 23551: 'NoneType' object is not iterable
# Error processing row 23552: 'NoneType' object is not iterable
# Error processing row 23553: 'NoneType' object is not iterable
# Error processing row 23554: 'NoneType' object is not iterable
# Error processing row 23555: 'NoneType' object is not iterable
# Error processing row 23556: 'NoneType' object is not iterable
# Error processing row 23557: 'NoneType' object is not iterable
# Error processing row 23558: 'NoneType' object is not iterable
# Error processing row 23559: 'NoneType' object is not iterable
# Error processing row 23560: 'NoneType' object is not iterable
# Error processing row 23561: 'NoneType' object is not iterable
# Error processing row 23562: 'NoneType' object is not iterable
# Error processing row 23563: 'NoneType' object is not iterable
# Error processing row 23564: 'NoneType' object is not iterable
# Error processing row 23565: 'NoneType' object is not iterable
# Error processing row 23566: 'NoneType' object is not iterable
# Error processing row 23567: 'NoneType' object is not iterable
# Error processing row 23568: 'NoneType' object is not iterable
# Error processing row 23569: 'NoneType' object is not iterable
# Error processing row 23570: 'NoneType' object is not iterable
# Error processing row 23571: 'NoneType' object is not iterable
# Error processing row 23572: 'NoneType' object is not iterable
# Error processing row 23573: 'NoneType' object is not iterable
# Error processing row 23574: 'NoneType' object is not iterable
# Error processing row 23575: 'NoneType' object is not iterable
# Error processing row 23576: 'NoneType' object is not iterable
# Error processing row 23577: 'NoneType' object is not iterable
# Error processing row 23578: 'NoneType' object is not iterable
# Error processing row 23579: 'NoneType' object is not iterable
# Error processing row 23580: 'NoneType' object is not iterable
# Error processing row 23581: 'NoneType' object is not iterable
# Error processing row 23582: 'NoneType' object is not iterable
# Error processing row 23583: 'NoneType' object is not iterable
# Error processing row 23584: 'NoneType' object is not iterable
# Error processing row 23585: 'NoneType' object is not iterable
# Error processing row 23586: 'NoneType' object is not iterable
# Error processing row 23587: 'NoneType' object is not iterable
# Error processing row 23588: 'NoneType' object is not iterable
# Error processing row 23589: 'NoneType' object is not iterable
# Error processing row 23590: 'NoneType' object is not iterable
# Error processing row 23591: 'NoneType' object is not iterable
# Error processing row 23592: 'NoneType' object is not iterable
# Error processing row 23593: 'NoneType' object is not iterable
# Error processing row 23594: 'NoneType' object is not iterable
# Error processing row 23595: 'NoneType' object is not iterable
# Error processing row 23596: 'NoneType' object is not iterable
# Error processing row 23597: 'NoneType' object is not iterable
# Error processing row 23598: 'NoneType' object is not iterable
# Error processing row 23599: 'NoneType' object is not iterable
# Error processing row 23600: 'NoneType' object is not iterable
# Error processing row 23601: 'NoneType' object is not iterable
# Error processing row 23602: 'NoneType' object is not iterable
# Error processing row 23603: 'NoneType' object is not iterable
# Error processing row 23604: 'NoneType' object is not iterable
# Error processing row 23605: 'NoneType' object is not iterable
# Error processing row 23606: 'NoneType' object is not iterable
# Error processing row 23607: 'NoneType' object is not iterable
# Error processing row 23608: 'NoneType' object is not iterable
# Error processing row 23609: 'NoneType' object is not iterable
# Error processing row 23610: 'NoneType' object is not iterable
# Error processing row 23611: 'NoneType' object is not iterable
# Error processing row 23612: 'NoneType' object is not iterable
# Error processing row 23613: 'NoneType' object is not iterable
# Error processing row 23614: 'NoneType' object is not iterable
# Error processing row 23615: 'NoneType' object is not iterable

# %% [markdown]
# Generate training df

# %%
rows = []
for ex in traffic_examples:
    user_msg = ""
    assistant_msg = ""
    for msg in ex["messages"]:
        if msg["role"] == "user":
            user_msg = msg["content"]
        elif msg["role"] == "assistant":
            assistant_msg = msg["content"]
    rows.append({"user_message": user_msg, "assistant_message": assistant_msg})

df_training = pd.DataFrame(rows)
df_training.to_csv("trainingdataset.csv", index=False, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 rows = []
# ----> 2 for ex in traffic_examples:
#       3     user_msg = ""
#       4     assistant_msg = ""
#
# NameError: name 'traffic_examples' is not defined

# %% [markdown]
# Read training df

# %%
df = pd.read_csv("../data/trainingdataset.csv")
traffic_examples = []
for _, row in df.iterrows():
    example = {
        "messages": [
            {"role": "user", "content": row["user_message"]},
            {"role": "assistant", "content": row["assistant_message"]}
        ]
    }
    traffic_examples.append(example)

print(traffic_examples[:2])
# Out:
# [{'messages': [{'role': 'user', 'content': 'B1: Nesre?eCesta RoÅ¾na Dolina - AjÅ¡evica je pri AjÅ¡evici zaprta.Cesta Pesek - Oplotnica je v Oplotnici zaprta.OpozorilaNa avtocesti od SeÅ¾ane proti Mariboru, do Slovenskih Konjic, pelje izredni prevoz. Ob?asno je lahko promet oviran in upo?asnjen.Mejni prehodi?akalna doba je na mejnem prehodu ObreÅ¾je.Tovorni prometZaradi praznikov bo po Sloveniji v nedeljo, 1. 5. in v ponedeljek, 2. 5. med 8. in 22. uro, veljala omejitev prometa tovornih vozil, katerih najve?ja dovoljena masa presega 7,5 t.'}, {'role': 'assistant', 'content': 'Zaradi prometne nesreče je zaprta regionalna cesta Ajševica-Rožna Dolina, in to pri Ajševici. Na mejnem prehodu Obrežje vozniki na vstop v državo čakajo do dve uri, v Gruškovju pa pol ure.  \nPovečan promet pri izstopu iz države pa je na prehodu Dobovec, na katerem vozniki čakajo uro in pol, ter na Obrežju in v Gruškovju, v katerem vozniki čakajo pol ure.\n'}]}, {'messages': [{'role': 'user', 'content': 'B1: Mejni prehodi?akalna doba je na mejnih prehodih ObreÅ¾je, Dobovec in GruÅ¡kovje.Tovorni prometZaradi praznikov bo po Sloveniji v nedeljo, 1. 5. in v ponedeljek, 2. 5. med 8. in 22. uro, veljala omejitev prometa tovornih vozil, katerih najve?ja dovoljena masa presega 7,5 t.'}, {'role': 'assistant', 'content': 'Zaradi pokvarjenega vozila je na štajerski avtocesti v predoru Jasovnik zaprt vozni pas proti Ljubljani. Na mejnih prehodih Sečovlje, Petrina, Dragonja in Dobovec vozniki osebnih vozil na izstop iz države čakajo približno pol ure; na Obrežju, v Gruškovju ter Slovenski vasi pa 1 uro pri vstopu v državo. '}]}]

# %% [markdown]
# Create joined file

# %%
input_df1 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")
input_df2 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")
input_df3 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")

joined_df = pd.concat([input_df1, input_df2, input_df3], ignore_index=True) 
joined_df.to_csv("PrometnoPorociloAll.csv", index=False, encoding="utf-8")
# Out:
# C:\Users\turkf\AppData\Local\Temp\ipykernel_6496\3840153283.py:2: DtypeWarning: Columns (6,19,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   input_df1 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")
# C:\Users\turkf\AppData\Local\Temp\ipykernel_6496\3840153283.py:3: DtypeWarning: Columns (6,19,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   input_df2 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")
# C:\Users\turkf\AppData\Local\Temp\ipykernel_6496\3840153283.py:4: DtypeWarning: Columns (6,19,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   input_df3 = pd.read_csv("../data/RTVSlo/PrometnoPorocilo2022.csv", encoding="Windows-1252")

# %%
from datasets import Dataset
dataset = Dataset.from_list(traffic_examples)
dataset = dataset.train_test_split(test_size=0.2)

print(dataset["train"])

# %%
# First, let's check what resources we have available
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("gpt2")
model.to("cuda")
def check_resources():
    print(f"CUDA available: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"GPU device: {torch.cuda.get_device_name(0)}")
        print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    
    import psutil
    print(f"CPU cores: {psutil.cpu_count(logical=False)} physical, {psutil.cpu_count()} logical")
    print(f"RAM: {psutil.virtual_memory().total / 1024**3:.2f} GB total")
    print(f"Available RAM: {psutil.virtual_memory().available / 1024**3:.2f} GB")

# Check resources before starting
check_resources()

# %%
from datasets import Dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer, DataCollatorForLanguageModeling

def train_model(model_id, dataset):

    model = AutoModelForCausalLM.from_pretrained(model_id)
    model.to("cuda")
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    
    def preprocess_function(examples):
        texts = []
        for conversation in examples["messages"]:
            formatted_text = ""
            for message in conversation:
                if message["role"] == "user":
                    formatted_text += f"Uporabnik: {message['content']}\n"
                else:
                    formatted_text += f"Asistent: {message['content']}\n"
            texts.append(formatted_text)
        
        tokenized = tokenizer(texts, padding="max_length", truncation=True, max_length=512)
        return tokenized
    
    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=6,
        per_device_eval_batch_size=6,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir="./logs",
        logging_steps=10,
    )
    
    data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer, 
        mlm=False  
    )
    
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["test"],
        data_collator=data_collator,
    )
    
    trainer.train()
    
    model.save_pretrained("./fine-tuned-traffic-model")
    tokenizer.save_pretrained("./fine-tuned-traffic-model")
    
    return model, tokenizer

#model_id = "cjvt/OPT_GaMS-1B-Chat"
model_id = "cjvt/OPT_GaMS-1B-Chat"
model, tokenizer = train_model(model_id, dataset)

# %%
torch.cuda.empty_cache()

# %%
import gc
import torch
from datasets import Dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer, DataCollatorForLanguageModeling

# First, clear memory
gc.collect()
torch.cuda.empty_cache() if torch.cuda.is_available() else None

# Example traffic data (small sample to test with)
traffic_examples = [
    {
        "messages": [
            {"role": "user", "content": "Generiraj poročilo o prometu za avtocesto A1 med Ljubljano in Mariborom."},
            {"role": "assistant", "content": "Na avtocesti A1 med Ljubljano in Mariborom trenutno ni posebnosti. Promet poteka tekoče v obeh smereh."}
        ]
    },
    {
        "messages": [
            {"role": "user", "content": "Stanje na cestah v Ljubljani?"},
            {"role": "assistant", "content": "V Ljubljani trenutno ni večjih zastojev. Na Celovški cesti so dela, ki upočasnjujejo promet."}
        ]
    }
]

# Create a smaller dataset for initial testing
dataset = Dataset.from_list(traffic_examples)
dataset = dataset.train_test_split(test_size=0.5)  # 50/50 split for this tiny example

def train_model(model_id, dataset, device_map="auto"):
    try:
        # More careful model loading with resource management
        print(f"Loading model from {model_id}...")
        print(f"Available GPU: {torch.cuda.is_available()}, Device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
        
        # Try to load with lower precision to save memory
        model = AutoModelForCausalLM.from_pretrained(
            model_id,
            device_map=device_map,       # Distribute across available GPUs or use CPU
            torch_dtype=torch.float16,   # Use half precision to save memory
            low_cpu_mem_usage=True       # More memory-efficient loading
        )
        
        print("Model loaded successfully")
        
        # Load tokenizer (this is usually much lighter)
        tokenizer = AutoTokenizer.from_pretrained(model_id)
        print("Tokenizer loaded successfully")
        
        def preprocess_function(examples):
            texts = []
            for conversation in examples["messages"]:
                formatted_text = ""
                for message in conversation:
                    if message["role"] == "user":
                        formatted_text += f"Uporabnik: {message['content']}\n"
                    else:
                        formatted_text += f"Asistent: {message['content']}\n"
                texts.append(formatted_text)
            
            tokenized = tokenizer(texts, padding="max_length", truncation=True, max_length=512)
            return tokenized
        
        # Process the dataset
        print("Preprocessing dataset...")
        tokenized_dataset = dataset.map(preprocess_function, batched=True)
        print("Dataset preprocessed successfully")
        
        # Training arguments with lower memory footprint
        training_args = TrainingArguments(
            output_dir="./results",
            num_train_epochs=1,             # Start with fewer epochs for testing
            per_device_train_batch_size=1,  # Smaller batch size
            per_device_eval_batch_size=1,   # Smaller batch size
            warmup_steps=10,                # Fewer warmup steps
            weight_decay=0.01,
            logging_dir="./logs",
            logging_steps=1,
            # Memory optimization settings
            gradient_accumulation_steps=4,  # Accumulate gradients to simulate larger batch
            fp16=torch.cuda.is_available(), # Use FP16 if GPU available
            dataloader_num_workers=0,       # Don't use multiple workers
        )
        
        # Create data collator
        data_collator = DataCollatorForLanguageModeling(
            tokenizer=tokenizer,
            mlm=False
        )
        
        # Create trainer
        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=tokenized_dataset["train"],
            eval_dataset=tokenized_dataset["test"],
            data_collator=data_collator,
        )
        
        print("Starting training...")
        trainer.train()
        print("Training completed")
        
        # Save model
        model.save_pretrained("./fine-tuned-traffic-model")
        tokenizer.save_pretrained("./fine-tuned-traffic-model")
        
        return model, tokenizer
        
    except Exception as e:
        print(f"Error during model loading or training: {e}")
        
        # If the error is related to CUDA out of memory, try CPU
        if "CUDA out of memory" in str(e) and device_map == "auto":
            print("GPU memory error detected. Trying to load on CPU instead...")
            return train_model(model_id, dataset, device_map="cpu")
        else:
            raise e

# Try loading with smaller model first to test
try:
    print("First trying a smaller model to verify environment...")
    small_model_id = "cjvt/OPT_SloT-300M-Chat"  # Much smaller model
    test_model = AutoModelForCausalLM.from_pretrained(small_model_id, torch_dtype=torch.float16)
    print("Small model loaded successfully, environment seems functional")
    del test_model  # Free the memory
    gc.collect()
    torch.cuda.empty_cache() if torch.cuda.is_available() else None
except Exception as e:
    print(f"Error loading test model: {e}")

# Now try the actual model
try:
    model_id = "cjvt/OPT_GaMS-1B-Chat"
    model, tokenizer = train_model(model_id, dataset)
except Exception as e:
    print(f"Failed to train model: {e}")
    print("Attempting to load model without training...")
    try:
        # Just load the model to check if that's possible
        model = AutoModelForCausalLM.from_pretrained(
            model_id, 
            device_map="cpu",
            torch_dtype=torch.float16
        )
        print("Model loaded successfully without training")
    except Exception as e2:
        print(f"Model loading also failed: {e2}")

# %%
from transformers import pipeline
def generate_traffic_report(prompt, model_path="./fine-tuned-traffic-model"):

    model = AutoModelForCausalLM.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    
    generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device_map="auto")
    
    formatted_input = f"Uporabnik: {prompt}\nAsistent:"
    
    response = generator(formatted_input, max_length=200, do_sample=True, temperature=0.7, truncation=True)
    
    assistant_response = response[0]["generated_text"].split("Asistent:")[1].strip()
    
    return assistant_response

# Example usage
prompt = "Poročaj o stanju na primorski avtocesti med Vrhniko in Koprom. Dela na cesti pri Postojni."
report = generate_traffic_report(prompt)
print(report)

# %%
from transformers import pipeline

def evaluate_model(model_path, test_examples):
    # Create evaluation dataset
    eval_dataset = Dataset.from_list(test_examples)
    
    # Load model and tokenizer
    model = AutoModelForCausalLM.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    
    # Create generator
    generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device_map="auto")
    
    # Evaluate on each example
    results = []
    for example in test_examples:
        user_input = example["messages"][0]["content"]
        expected_output = example["messages"][1]["content"]
        
        # Generate response
        formatted_input = f"Uporabnik: {user_input}\nAsistent:"
        response = generator(formatted_input, max_length=200)
        generated = response[0]["generated_text"].split("Asistent:")[1].strip()
        
        # Store results
        results.append({
            "input": user_input,
            "expected": expected_output,
            "generated": generated
        })
    
    return results

# Example evaluation
test_examples = [
    {
        "messages": [
            {"role": "user", "content": "Kakšno je stanje na gorenjski avtocesti proti Jesenicam?"},
            {"role": "assistant", "content": "Na gorenjski avtocesti proti Jesenicam trenutno ni posebnosti ali zastojev. Promet poteka tekoče na celotnem odseku."}
        ]
    }
]

evaluation_results = evaluate_model("./fine-tuned-traffic-model", test_examples)
print(evaluation_results)

# %% [markdown]
# Evaluation will then follow next procedures.:
#
# 1. Consistent Examples in Training Data
# The most straightforward approach is providing numerous consistent examples:
#
# Include many examples with correct road naming formats
# Ensure consistency across all training examples
# Cover all variations of road types (highways, regional roads, streets)
#
# For example, always using formats like:
#
# "avtocesta A1" (not just "A1")
# "regionalna cesta R2-409" (with full designation)
# "Celovška cesta" (with proper capitalization)
#
# 2. Instruction-Based Fine-tuning
# You can explicitly teach the model road naming rules:
# pythonroad_naming_examples = [
#     {
#         "messages": [
#             {"role": "user", "content": "Kako pravilno poimenovati avtocesto A1?"},
#             {"role": "assistant", "content": "Avtocesta A1 se pravilno imenuje 'avtocesta A1' ali 'avtocesta A1 Šentilj-Srmin'. Pri prvem omenjanju v poročilu uporabite polno ime, kasneje lahko uporabite krajšo obliko 'A1'."}
#         ]
#     },
#     {
#         "messages": [
#             {"role": "user", "content": "Navedi pravila za poimenovanje cest v prometnih poročilih."},
#             {"role": "assistant", "content": "Pri poimenovanju cest v prometnih poročilih upoštevajte naslednja pravila:\n1. Avtoceste: 'avtocesta A1', ne samo 'A1'\n2. Hitre ceste: 'hitra cesta H4', ne samo 'H4'\n3. Regionalne ceste: 'regionalna cesta R2-409'\n4. Mestne ceste: uporabite polno ime, npr. 'Celovška cesta', ne 'Celovška'"}
#         ]
#     }
# ]
# Add these instructional examples to your training data to explicitly teach rules.
# 3. Data Augmentation with Rule Enforcement
# Create augmented examples that specifically focus on proper naming:
# python# Original example
# original = {
#     "messages": [
#         {"role": "user", "content": "Poročaj o stanju na A1."},
#         {"role": "assistant", "content": "Na avtocesti A1 med Ljubljano in Mariborom trenutno ni zastojev."}
#     ]
# }
#
# # Add variations with correct naming to reinforce the rule
# variations = [
#     {
#         "messages": [
#             {"role": "user", "content": "Poročaj o stanju na A1 proti Mariboru."},
#             {"role": "assistant", "content": "Na avtocesti A1 v smeri proti Mariboru trenutno ni posebnosti."}
#         ]
#     },
#     {
#         "messages": [
#             {"role": "user", "content": "Kako je na A1?"},
#             {"role": "assistant", "content": "Na avtocesti A1 Šentilj-Srmin je promet tekoč v obeh smereh."}
#         ]
#     }
# ]
# 4. Post-Processing Rules
# For critical naming conventions, you can implement post-processing:
# pythondef enforce_road_naming(generated_text):
#     # Dictionary of road type patterns and their correct forms
#     road_patterns = {
#         r'\b(A\d+)\b(?! avtocest)': r'avtocesta \1',  # A1 → avtocesta A1
#         r'\b(H\d+)\b(?! hitr)': r'hitra cesta \1',    # H4 → hitra cesta H4
#         # Add more patterns as needed
#     }
#
#     # Apply all patterns
#     result = generated_text
#     for pattern, replacement in road_patterns.items():
#         result = re.sub(pattern, replacement, result)
#
#     return result
#
# # Use this after generation
# response = generate_traffic_report(prompt)
# corrected_response = enforce_road_naming(response)
# 5. Evaluation and Filtering
# Create a specific evaluation metric for road naming compliance:
# pythondef evaluate_road_naming(generated_text):
#     # Define patterns for improper road naming
#     improper_patterns = [
#         r'\b(A\d+)\b(?! avtocest)',  # A1 without "avtocesta"
#         r'\b(H\d+)\b(?! hitr)',      # H4 without "hitra cesta"
#         # Add more patterns
#     ]
#
#     # Count violations
#     violations = 0
#     for pattern in improper_patterns:
#         violations += len(re.findall(pattern, generated_text))
#
#     return {
#         "violations": violations,
#         "compliant": violations == 0
#     }
# Practical Implementation Approach
# Here's how I recommend implementing these strategies:
#
# Start with data quality: Ensure all your training examples use correct road naming
# Add instruction examples: Include specific examples teaching the naming rules
# Evaluate during development: Create a custom metric to track naming compliance
# Implement post-processing: As a safety net for critical applications
#
# By combining these approaches, you'll significantly improve your model's adherence to specific road naming conventions while still maintaining natural-sounding Slovenian text.
# Would you like me to elaborate on any of these strategies or provide more specific examples for Slovenian road naming conventions?

# %% [markdown]
# Zero shot prompting

# %% [markdown]
# few shot prompting with all the rules exmplained?
